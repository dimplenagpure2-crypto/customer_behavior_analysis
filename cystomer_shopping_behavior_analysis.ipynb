# %%
import pandas as pd
from sqlalchemy import create_engine
from sqlalchemy.engine import URL

# Load your file
df = pd.read_excel(r"C:\Users\dimpl\Downloads\customer_shopping_behavior.csv.xlsx")
# If it's a CSV, use:
# df = pd.read_csv(r"C:\Users\dimpl\Downloads\customer_shopping_behavior.csv")

url = URL.create(
    drivername="postgresql+psycopg2",
    username="postgres",
    password="dimple@11",   # Replace with the actual PostgreSQL password
    host="localhost",
    port=5432,
    database="customer_behavior"
)

engine = create_engine(url)

table_name = "customer"

df.to_sql(table_name, engine, if_exists="replace", index=False)

print(f"Data successfully loaded into table '{table_name}' in database '{url.database}'.")
# Out:
# Data successfully loaded into table 'customer' in database 'customer_behavior'.
